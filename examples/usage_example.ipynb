# %%
import sys  
sys.path.insert(0, '../marie')

# %%
import marie
import time

# %%
source_dataset="../data/input.txt"
target_dataset="../data/target.txt"
source_weight="../data/input.jsonl"
target_weight="../data/target.jsonl"

# %%
start_time=time.time()
mapper, inp_idx2txt, tgt_idx2txt = marie.map_marie(source_dataset, target_dataset, source_weight, target_weight)
print(time.time()-start_time)
# Out:
# ...Processed 0 mappings
# ...Processed 100 mappings
# ...Processed 200 mappings
# ...Processed 300 mappings
# ...Processed 400 mappings
# ...Processed 500 mappings
# ...Processed 600 mappings
# ...Processed 700 mappings
# ...Processed 800 mappings
# ...Processed 900 mappings
# ...Processed 1000 mappings
# ...Processed 1100 mappings
# ...Processed 1200 mappings
# ...Processed 1300 mappings
# ...Processed 1400 mappings
# ...Processed 1500 mappings
# ...Processed 1600 mappings
# ...Processed 1700 mappings
# ...Processed 1800 mappings
# ...Processed 1900 mappings
# ...Processed 2000 mappings
# ...Processed 2100 mappings
# ...Processed 2200 mappings
# ...Processed 2300 mappings
# ...Processed 2400 mappings
# ...Processed 2500 mappings
# ...Processed 2600 mappings
# ...Processed 2700 mappings
# ...Processed 2800 mappings
# ...Processed 2900 mappings
# ...Processed 3000 mappings
# ...Processed 3100 mappings
# ...Processed 3200 mappings
# ...Processed 3300 mappings
# ...

# %%
for key, value in mapper.items():
    print(inp_idx2txt[key])
    print([tgt_idx2txt[target[0]] for target in value])
# Out:
# amlodipine / olmesartan / hydrochlorothiazide 10 mg / 40 mg / 12.5 mg tab
# ['amlodipine 5 mg / hydrochlorothiazide 12.5 mg / olmesartan medoxomil 40 mg oral tablet', 'amlodipine 5 mg / hydrochlorothiazide 12.5 mg / olmesartan medoxomil 20 mg oral tablet', 'amlodipine 10 mg / hydrochlorothiazide 12.5 mg / olmesartan medoxomil 40 mg oral tablet', 'eprosartan 600 mg / hydrochlorothiazide 12.5 mg oral tablet', 'amlodipine 5 mg / olmesartan medoxomil 20 mg oral tablet']
# amlodipine / olmesartan / hydrochlorothiazide 5 mg / 20 mg / 12.5 mg tab
# ['amlodipine 5 mg / hydrochlorothiazide 12.5 mg / olmesartan medoxomil 40 mg oral tablet', 'amlodipine 5 mg / hydrochlorothiazide 12.5 mg / olmesartan medoxomil 20 mg oral tablet', 'amlodipine 10 mg / hydrochlorothiazide 12.5 mg / olmesartan medoxomil 40 mg oral tablet', 'eprosartan 600 mg / hydrochlorothiazide 12.5 mg oral tablet', 'amlodipine 5 mg / olmesartan medoxomil 20 mg oral tablet']
# ...
