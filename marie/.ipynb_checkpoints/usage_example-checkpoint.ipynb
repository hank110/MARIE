# %%
import marie
import time

# %%
source_dataset="input_path_location"
target_dataset="target_path_location"
source_weight="source_biobert_weights.jsonl"
target_weight="target_biobert_weights.jsonl"

# %%
start_time=time.time()
mapper, inp_idx2txt, tgt_idx2txt = marie.map_metis(source_dataset, target_dataset, source_weight, target_weight)
print(time.time()-start_time)
# Out:
# ...Processed 0 mappings
# ...Processed 100 mappings
# ...Processed 200 mappings
# ...Processed 300 mappings
# ...Processed 400 mappings
# ...Processed 500 mappings
# ...Processed 600 mappings
# ...Processed 700 mappings
# ...Processed 800 mappings
# ...Processed 900 mappings
# ...Processed 1000 mappings
# ...Processed 1100 mappings
# ...Processed 1200 mappings
# ...Processed 1300 mappings
# ...Processed 1400 mappings
# ...Processed 1500 mappings
# ...Processed 1600 mappings
# ...Processed 1700 mappings
# ...Processed 1800 mappings
# ...Processed 1900 mappings
# ...Processed 2000 mappings
# ...Processed 2100 mappings
# ...Processed 2200 mappings
# ...Processed 2300 mappings
# ...Processed 2400 mappings
# ...Processed 2500 mappings
# ...Processed 2600 mappings
# ...Processed 2700 mappings
# ...Processed 2800 mappings
# ...Processed 2900 mappings
# ...Processed 3000 mappings
# ...Processed 3100 mappings
# ...Processed 3200 mappings
# ...Processed 3300 mappings
# ...

# %%
mapper
# Out:
# {0: [(2, 0.8656667511397417),
#   (1, 0.8656588680242573),
#   (0, 0.8637448465277341),
#   (722, 0.8381759969381006),
#   (109, 0.8370111413242718)],
#  1: [(2, 0.8652319668555901),
#   (1, 0.8651908383529214),
#   (0, 0.863500314004136),
#   (722, 0.8389977000681486),
#   (109, 0.8366193609192846)],
#  2: [(2, 0.8666089051176348),
#   (1, 0.8665549990476636),
#   (0, 0.8648012242997282),
#   (722, 0.8392836943279604),
#   (1783, 0.8381008378687633)],
#  3: [(3, 0.9319911143300921),
#   (4, 0.9198374663647488),
#   (2250, 0.8992427680191317),
#   (2125, 0.850109922060555),
#   (2122, 0.8495082180544786)],
#  4: [(4, 0.943196774119357),
#   (3, 0.8961471163812502),
#   (2250, 0.8759186937620731),
#   (1320, 0.8551349507266225),
#   (666, 0.8532370711867017)],
#  5: [(5, 0.9342132667127088),
#   (1620, 0.922682989327722),
#   (6, 0.9214270096079419),
#   (8, 0.9173715224462363),
#   (9, 0.9030335964347467)],
#  6: [(6, 0.9336144238037727),
#   (1620, 0.9218136906033572),
# ...
